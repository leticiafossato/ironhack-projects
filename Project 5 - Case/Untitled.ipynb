# %%
import pandas as pd

# %%
# !cd
# Out:
# C:\Users\Leticia\Documents\ironhack-projects\Project 5 - Case

# %%
pd.read_csv('data/rain_data_aus.csv')
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         sunshine  humidity9am  humidity3pm  pressure9am  ...  temp9am  \
# ...

# %%
pd.read_csv('data/wind_table_01.csv')
# Out:
#              date       location wind_gustdir  wind_gustspeed wind_dir9am  \
# 0      2007-11-01       Canberra           NW            30.0          SW
# 1      2007-11-02       Canberra          ENE            39.0           E
# 2      2007-11-03       Canberra           NW            85.0           N
# 3      2007-11-04       Canberra           NW            54.0         WNW
# 4      2007-11-05       Canberra          SSE            50.0         SSE
# ...           ...            ...          ...             ...         ...
# 19995  2010-01-25      Newcastle          NaN             NaN          SE
# 19996  2010-01-25      NorahHead           NE            37.0         SSW
# 19997  2010-01-25  NorfolkIsland            S            28.0           E
# 19998  2010-01-25       Richmond          ENE            33.0         NaN
# 19999  2010-01-25         Sydney          NaN             NaN         WNW
#
#       wind_dir3pm  wind_speed9am  wind_speed3pm
# ...

# %%
pd.read_csv('data/wind_table_02.csv')
# Out:
#              date       location wind_gustdir  wind_gustspeed wind_dir9am  \
# 0      2010-01-25  SydneyAirport            E            31.0         ESE
# 1      2010-01-25     WaggaWagga            W            33.0         ENE
# 2      2010-01-25    Williamtown            E            39.0         SSW
# 3      2010-01-25     Wollongong           NE            20.0         SSW
# 4      2010-01-25       Canberra          NaN             NaN         NaN
# ...           ...            ...          ...             ...         ...
# 19995  2011-05-14          Cobar           SW            35.0         SSW
# 19996  2011-05-14   CoffsHarbour           SW            33.0         WSW
# 19997  2011-05-14          Moree          WSW            56.0          SW
# 19998  2011-05-14      Newcastle          NaN             NaN          SW
# 19999  2011-05-14      NorahHead           SW            39.0         WSW
#
#       wind_dir3pm  wind_speed9am  wind_speed3pm
# ...

# %%
pd.read_csv('data/wind_table_03.csv')
# Out:
#              date          location windgustdir  windgustspeed winddir9am  \
# 0      2011-05-14     NorfolkIsland         WNW           50.0          W
# 1      2011-05-14           Penrith          SW           41.0         SW
# 2      2011-05-14          Richmond          SW           41.0        WSW
# 3      2011-05-14            Sydney         WSW           52.0          W
# 4      2011-05-14     SydneyAirport          SW           61.0          W
# ...           ...               ...         ...            ...        ...
# 19995  2012-07-31          Ballarat          SE           37.0          S
# 19996  2012-07-31           Bendigo         SSE           37.0          S
# 19997  2012-07-31              Sale          SW           22.0        WNW
# 19998  2012-07-31  MelbourneAirport         SSE           33.0        SSW
# 19999  2012-07-31         Melbourne         SSE           33.0        SSW
#
#       winddir3pm  windspeed9am  windspeed3pm
# ...

# %%
pd.read_csv('data/wind_table_04.csv')
# Out:
#              date      location windgustdir  windgustspeed winddir9am  \
# 0      2012-07-31       Mildura           S           30.0          S
# 1      2012-07-31      Portland          SE           26.0         SE
# 2      2012-07-31      Watsonia         ESE           24.0        NaN
# 3      2012-07-31      Dartmoor         ESE           20.0        NaN
# 4      2012-07-31      Brisbane          SW           22.0        SSW
# ...           ...           ...         ...            ...        ...
# 19995  2013-11-29         Cobar           S           48.0          S
# 19996  2013-11-29  CoffsHarbour           S           50.0         NE
# 19997  2013-11-29         Moree          SW           48.0          W
# 19998  2013-11-29     Newcastle         NaN            NaN        NaN
# 19999  2013-11-29     NorahHead         SSW           67.0          S
#
#       winddir3pm  windspeed9am  windspeed3pm
# 0            SSW           9.0          20.0
# ...

# %%
pd.read_csv('data/wind_table_05.csv')
# Out:
#              date       location windgustdir  windgustspeed winddir9am  \
# 0      2013-11-29  NorfolkIsland         WNW           31.0        WSW
# 1      2013-11-29        Penrith         SSE           39.0        NNE
# 2      2013-11-29       Richmond          SE           44.0        NaN
# 3      2013-11-29         Sydney           S           59.0        SSE
# 4      2013-11-29  SydneyAirport         SSW           69.0          S
# ...           ...            ...         ...            ...        ...
# 19995  2015-01-22   MountGambier          SW           48.0         NE
# 19996  2015-01-22      Nuriootpa          SW           43.0        ENE
# 19997  2015-01-22        Woomera         SSE           46.0         SE
# 19998  2015-01-22         Albany         NaN            NaN        WSW
# 19999  2015-01-22    Witchcliffe          SE           41.0         SE
#
#       winddir3pm  windspeed9am  windspeed3pm
# 0             NW          15.0          17.0
# ...

# %%
pd.read_csv('data/wind_table_06.csv')
# Out:
#              date          location windgustdir  windgustspeed winddir9am  \
# 0      2015-01-22        PearceRAAF          SW           37.0        SSE
# 1      2015-01-22      PerthAirport           W           37.0        ESE
# 2      2015-01-22             Perth          SW           35.0         SE
# 3      2015-01-22        SalmonGums           S           41.0          S
# 4      2015-01-22           Walpole           S           35.0         SW
# ...           ...               ...         ...            ...        ...
# 19995  2016-03-21          Ballarat          SE           48.0        ESE
# 19996  2016-03-21           Bendigo          SE           33.0         SE
# 19997  2016-03-21              Sale          SE           35.0          W
# 19998  2016-03-21  MelbourneAirport           S           43.0          W
# 19999  2016-03-21           Mildura          SE           33.0        SSE
#
#       winddir3pm  windspeed9am  windspeed3pm
# ...

# %%
sete = pd.read_csv('data/wind_table_07.csv')

# %%
oito = pd.read_csv('data/wind_table_08.csv')

# %%
oito[(sete['windgustspeed']!=oito['windgustspeed'])==False]
# Out:
#              date    location windgustdir  windgustspeed winddir9am  \
# 0      2016-03-21        Nhil         ESE           37.0        SSE
# 1      2016-03-21    Portland          SE           35.0        ENE
# 2      2016-03-21    Watsonia         SSW           35.0          E
# 3      2016-03-21    Dartmoor         ESE           44.0        ESE
# 4      2016-03-21    Brisbane         ESE           31.0          S
# ...           ...         ...         ...            ...        ...
# 22188  2017-06-25       Perth           E           26.0         SE
# 22189  2017-06-25  SalmonGums          SE           15.0        SSE
# 22190  2017-06-25     Walpole         SSW           20.0        WNW
# 22191  2017-06-25      Hobart          NW           50.0        NNW
# 22192  2017-06-25  Launceston          NW           50.0        NNW
#
#       winddir3pm  windspeed9am  windspeed3pm
# 0            SSE           9.0          15.0
# 1              E           7.0          20.0
# ...

# %%
sete[(sete['winddir9am']==oito['winddir9am'])==False]
# Out:
#              date    location windgustdir  windgustspeed winddir9am  \
# 0      2016-03-21        Nhil         ESE           37.0        SSE
# 1      2016-03-21    Portland          SE           35.0        ENE
# 2      2016-03-21    Watsonia         SSW           35.0          E
# 3      2016-03-21    Dartmoor         ESE           44.0        ESE
# 4      2016-03-21    Brisbane         ESE           31.0          S
# ...           ...         ...         ...            ...        ...
# 22188  2017-06-25       Perth           E           26.0         SE
# 22189  2017-06-25  SalmonGums          SE           15.0        SSE
# 22190  2017-06-25     Walpole         SSW           20.0        WNW
# 22191  2017-06-25      Hobart          NW           50.0        NNW
# 22192  2017-06-25  Launceston          NW           50.0        NNW
#
#       winddir3pm  windspeed9am  windspeed3pm
# 0            SSE           9.0          15.0
# 1              E           7.0          20.0
# ...

# %%
oito[(sete['winddir3pm']!=oito['winddir3pm'])]
# Out:
#              date   location windgustdir  windgustspeed winddir9am winddir3pm  \
# 12     2016-03-21     Albany         NaN            NaN          E        NaN
# 30     2016-03-22  Newcastle         NaN            NaN         NE        NaN
# 60     2016-03-22     Albany         NaN            NaN         SE        NaN
# 78     2016-03-23  Newcastle         NaN            NaN        NaN        NaN
# 108    2016-03-23     Albany         NaN            NaN         SE        NaN
# ...           ...        ...         ...            ...        ...        ...
# 22110  2017-06-24  Newcastle         NaN            NaN         NW        NaN
# 22128  2017-06-24    Mildura         SSW           15.0        NaN        NaN
# 22141  2017-06-24     Albany         NaN            NaN         SE        NaN
# 22153  2017-06-25     Albury         NNW           28.0          S        NaN
# 22184  2017-06-25     Albany         NaN            NaN          W        NaN
#
# ...

# %%
sete[(sete['winddir3pm']!=oito['winddir3pm'])]
# Out:
#              date   location windgustdir  windgustspeed winddir9am winddir3pm  \
# 12     2016-03-21     Albany         NaN            NaN          E        NaN
# 30     2016-03-22  Newcastle         NaN            NaN         NE        NaN
# 60     2016-03-22     Albany         NaN            NaN         SE        NaN
# 78     2016-03-23  Newcastle         NaN            NaN        NaN        NaN
# 108    2016-03-23     Albany         NaN            NaN         SE        NaN
# ...           ...        ...         ...            ...        ...        ...
# 22110  2017-06-24  Newcastle         NaN            NaN         NW        NaN
# 22128  2017-06-24    Mildura         SSW           15.0        NaN        NaN
# 22141  2017-06-24     Albany         NaN            NaN         SE        NaN
# 22153  2017-06-25     Albury         NNW           28.0          S        NaN
# 22184  2017-06-25     Albany         NaN            NaN          W        NaN
#
# ...

# %%
oito[(sete['winddir9am']!=oito['winddir9am'])]
# Out:
#              date       location windgustdir  windgustspeed winddir9am  \
# 8      2016-03-21       Adelaide         WSW           28.0        NaN
# 22     2016-03-21         Darwin          NW           33.0        NaN
# 23     2016-03-21      Katherine         ESE           20.0        NaN
# 37     2016-03-22     WaggaWagga          SW           28.0        NaN
# 56     2016-03-22       Adelaide           N           28.0        NaN
# ...           ...            ...         ...            ...        ...
# 22150  2017-06-24   AliceSprings         SSE           20.0        NaN
# 22154  2017-06-25  BadgerysCreek         WSW           31.0        NaN
# 22161  2017-06-25       Richmond           W           37.0        NaN
# 22175  2017-06-25        Mildura          SW           31.0        NaN
# 22185  2017-06-25    Witchcliffe         SSE           20.0        NaN
#
#       winddir3pm  windspeed9am  windspeed3pm
# 8             SW           0.0          13.0
# ...

# %%
sete[(sete['winddir9am']!=oito['winddir9am'])]
# Out:
#              date       location windgustdir  windgustspeed winddir9am  \
# 8      2016-03-21       Adelaide         WSW           28.0        NaN
# 22     2016-03-21         Darwin          NW           33.0        NaN
# 23     2016-03-21      Katherine         ESE           20.0        NaN
# 37     2016-03-22     WaggaWagga          SW           28.0        NaN
# 56     2016-03-22       Adelaide           N           28.0        NaN
# ...           ...            ...         ...            ...        ...
# 22150  2017-06-24   AliceSprings         SSE           20.0        NaN
# 22154  2017-06-25  BadgerysCreek         WSW           31.0        NaN
# 22161  2017-06-25       Richmond           W           37.0        NaN
# 22175  2017-06-25        Mildura          SW           31.0        NaN
# 22185  2017-06-25    Witchcliffe         SSE           20.0        NaN
#
#       winddir3pm  windspeed9am  windspeed3pm
# 8             SW           0.0          13.0
# ...

# %%
oito[(sete['winddir9am']!=oito['winddir9am'])]
# Out:
#              date       location windgustdir  windgustspeed winddir9am  \
# 8      2016-03-21       Adelaide         WSW           28.0        NaN
# 22     2016-03-21         Darwin          NW           33.0        NaN
# 23     2016-03-21      Katherine         ESE           20.0        NaN
# 37     2016-03-22     WaggaWagga          SW           28.0        NaN
# 56     2016-03-22       Adelaide           N           28.0        NaN
# ...           ...            ...         ...            ...        ...
# 22150  2017-06-24   AliceSprings         SSE           20.0        NaN
# 22154  2017-06-25  BadgerysCreek         WSW           31.0        NaN
# 22161  2017-06-25       Richmond           W           37.0        NaN
# 22175  2017-06-25        Mildura          SW           31.0        NaN
# 22185  2017-06-25    Witchcliffe         SSE           20.0        NaN
#
#       winddir3pm  windspeed9am  windspeed3pm
# 8             SW           0.0          13.0
# ...

# %%
oito[(sete['winddir3pm']!=oito['winddir3pm'])==False]
# Out:
#              date    location windgustdir  windgustspeed winddir9am  \
# 0      2016-03-21        Nhil         ESE           37.0        SSE
# 1      2016-03-21    Portland          SE           35.0        ENE
# 2      2016-03-21    Watsonia         SSW           35.0          E
# 3      2016-03-21    Dartmoor         ESE           44.0        ESE
# 4      2016-03-21    Brisbane         ESE           31.0          S
# ...           ...         ...         ...            ...        ...
# 22188  2017-06-25       Perth           E           26.0         SE
# 22189  2017-06-25  SalmonGums          SE           15.0        SSE
# 22190  2017-06-25     Walpole         SSW           20.0        WNW
# 22191  2017-06-25      Hobart          NW           50.0        NNW
# 22192  2017-06-25  Launceston          NW           50.0        NNW
#
#       winddir3pm  windspeed9am  windspeed3pm
# 0            SSE           9.0          15.0
# 1              E           7.0          20.0
# ...

# %%
sete[(sete['winddir3pm']==oito['winddir3pm'])==False]
# Out:
#              date   location windgustdir  windgustspeed winddir9am winddir3pm  \
# 12     2016-03-21     Albany         NaN            NaN          E        NaN
# 30     2016-03-22  Newcastle         NaN            NaN         NE        NaN
# 60     2016-03-22     Albany         NaN            NaN         SE        NaN
# 78     2016-03-23  Newcastle         NaN            NaN        NaN        NaN
# 108    2016-03-23     Albany         NaN            NaN         SE        NaN
# ...           ...        ...         ...            ...        ...        ...
# 22110  2017-06-24  Newcastle         NaN            NaN         NW        NaN
# 22128  2017-06-24    Mildura         SSW           15.0        NaN        NaN
# 22141  2017-06-24     Albany         NaN            NaN         SE        NaN
# 22153  2017-06-25     Albury         NNW           28.0          S        NaN
# 22184  2017-06-25     Albany         NaN            NaN          W        NaN
#
# ...

# %%
oito[(sete['windspeed9am']!=oito['windspeed9am'])]
# Out:
#              date       location windgustdir  windgustspeed winddir9am  \
# 203    2016-03-25         Albany         NaN            NaN        NaN
# 893    2016-04-09      Newcastle         NaN            NaN        NaN
# 1656   2016-04-25      Newcastle         NaN            NaN        NaN
# 2042   2016-05-03  NorfolkIsland          NE           41.0        NaN
# 2875   2016-05-20       Canberra         WNW           41.0        NaN
# ...           ...            ...         ...            ...        ...
# 20648  2017-05-24         Albany         NaN            NaN        NaN
# 20763  2017-05-27      Newcastle         NaN            NaN        NaN
# 21318  2017-06-07         Albany         NaN            NaN        NaN
# 21658  2017-06-14         Albany         NaN            NaN        NaN
# 21995  2017-06-21         Albany         NaN            NaN        NaN
#
#       winddir3pm  windspeed9am  windspeed3pm
# 203          NaN           NaN           NaN
# ...

# %%
sete[(sete['windspeed9am']!=oito['windspeed9am'])]
# Out:
#              date       location windgustdir  windgustspeed winddir9am  \
# 203    2016-03-25         Albany         NaN            NaN        NaN
# 893    2016-04-09      Newcastle         NaN            NaN        NaN
# 1656   2016-04-25      Newcastle         NaN            NaN        NaN
# 2042   2016-05-03  NorfolkIsland          NE           41.0        NaN
# 2875   2016-05-20       Canberra         WNW           41.0        NaN
# ...           ...            ...         ...            ...        ...
# 20648  2017-05-24         Albany         NaN            NaN        NaN
# 20763  2017-05-27      Newcastle         NaN            NaN        NaN
# 21318  2017-06-07         Albany         NaN            NaN        NaN
# 21658  2017-06-14         Albany         NaN            NaN        NaN
# 21995  2017-06-21         Albany         NaN            NaN        NaN
#
#       winddir3pm  windspeed9am  windspeed3pm
# 203          NaN           NaN           NaN
# ...

# %%
sete[(sete['windspeed3pm']!=oito['windspeed3pm'])]
# Out:
#              date   location windgustdir  windgustspeed winddir9am winddir3pm  \
# 12     2016-03-21     Albany         NaN            NaN          E        NaN
# 30     2016-03-22  Newcastle         NaN            NaN         NE        NaN
# 60     2016-03-22     Albany         NaN            NaN         SE        NaN
# 78     2016-03-23  Newcastle         NaN            NaN        NaN        NaN
# 108    2016-03-23     Albany         NaN            NaN         SE        NaN
# ...           ...        ...         ...            ...        ...        ...
# 22061  2017-06-23  Newcastle         NaN            NaN         SW        NaN
# 22092  2017-06-23     Albany         NaN            NaN         SE        NaN
# 22110  2017-06-24  Newcastle         NaN            NaN         NW        NaN
# 22141  2017-06-24     Albany         NaN            NaN         SE        NaN
# 22184  2017-06-25     Albany         NaN            NaN          W        NaN
#
# ...

# %%
oito[(sete['windspeed3pm']!=oito['windspeed3pm'])]
# Out:
#              date   location windgustdir  windgustspeed winddir9am winddir3pm  \
# 12     2016-03-21     Albany         NaN            NaN          E        NaN
# 30     2016-03-22  Newcastle         NaN            NaN         NE        NaN
# 60     2016-03-22     Albany         NaN            NaN         SE        NaN
# 78     2016-03-23  Newcastle         NaN            NaN        NaN        NaN
# 108    2016-03-23     Albany         NaN            NaN         SE        NaN
# ...           ...        ...         ...            ...        ...        ...
# 22061  2017-06-23  Newcastle         NaN            NaN         SW        NaN
# 22092  2017-06-23     Albany         NaN            NaN         SE        NaN
# 22110  2017-06-24  Newcastle         NaN            NaN         NW        NaN
# 22141  2017-06-24     Albany         NaN            NaN         SE        NaN
# 22184  2017-06-25     Albany         NaN            NaN          W        NaN
#
# ...
