# %% [markdown]
# # HOW MANY ACCIDENTS WAS FATAL, NOT FATAL OR UNKNOWN?
# ##   SHARK ATTACK DATABASE ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
# !cd
# Out:
# C:\Users\letic\Documents\ironhack-projects\Week 2 - Shark Attacks

# %%
#Importing the dataset
shark = pd.read_csv('attacks.csv', encoding='latin1')
#Analysing a sample of dataset
shark.sample(5)
# Out:
#         Case Number         Date    Year          Type      Country  \
# 22385           NaN          NaN     NaN           NaN          NaN
# 22238           NaN          NaN     NaN           NaN          NaN
# 13955           NaN          NaN     NaN           NaN          NaN
# 8955            NaN          NaN     NaN           NaN          NaN
# 4637   1944.10.25.b  25-Oct-1944  1944.0  Sea Disaster  PHILIPPINES
#
#                                         Area Location  \
# 22385                                    NaN      NaN
# 22238                                    NaN      NaN
# 13955                                    NaN      NaN
# 8955                                     NaN      NaN
# 4637   Off Samar Island in the Gulf of Leyte      NaN
#
#                                                 Activity  \
# 22385                                                NaN
# 22238                                                NaN
# 13955                                                NaN
# 8955                                                 NaN
# 4637   USS Johnston DD 557 sunk on 10/24/1944 in the ...
#
#                                             Name Sex   Age  \
# 22385                                        NaN  NaN  NaN
# 22238                                        NaN  NaN  NaN
# 13955                                        NaN  NaN  NaN
# 8955                                         NaN  NaN  NaN
# 4637   William Clinton Carter, Jr. & 2 other men    M  NaN
#
#                                                   Injury Fatal (Y/N) Time  \
# 22385                                                NaN         NaN  NaN
# 22238                                                NaN         NaN  NaN
# 13955                                                NaN         NaN  NaN
# 8955                                                 NaN         NaN  NaN
# 4637   Clinton was bitten on his back, 2 others did n...           Y  NaN
#
#       Species              Investigator or Source                      pdf  \
# 22385      NaN                                NaN                      NaN
# 22238      NaN                                NaN                      NaN
# 13955      NaN                                NaN                      NaN
# 8955       NaN                                NaN                      NaN
# 4637       NaN  Abiline Reporter News, 12/29/1944  1944.10.25.b-Carter.pdf
#
#                                             href formula  \
# 22385                                                NaN
# 22238                                                NaN
# 13955                                                NaN
# 8955                                                 NaN
# 4637   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                     href Case Number.1  \
# 22385                                                NaN           NaN
# 22238                                                NaN           NaN
# 13955                                                NaN           NaN
# 8955                                                 NaN           NaN
# 4637   http://sharkattackfile.net/spreadsheets/pdf_di...  1944.10.25.b
#
#       Case Number.2  original order Unnamed: 22 Unnamed: 23
# 22385           NaN             NaN         NaN         NaN
# 22238           NaN             NaN         NaN         NaN
# 13955           NaN             NaN         NaN         NaN
# 8955            NaN             NaN         NaN         NaN
# 4637   1944.10.25.b          1666.0         NaN         NaN

# %%
#Analysing the quantity of lines and columns
shark.shape
# Out:
# (25723, 24)

# %%
#Creating a backup before start to drop columns
shark_bkp = shark.copy()

# %% [markdown]
# ## CLEANING LINES

# %%
#Analysing the % of lines null
shark.isnull().mean(axis=1)
# Out:
# 0        0.083333
# 1        0.125000
# 2        0.125000
# 3        0.166667
# 4        0.166667
#            ...
# 25718    1.000000
# 25719    1.000000
# 25720    1.000000
# 25721    1.000000
# 25722    0.958333
# Length: 25723, dtype: float64

# %%
#Mask to drop the lines which more than 90% of NaN 
shark.isnull().mean(axis=1)>0.9
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25718     True
# 25719     True
# 25720     True
# 25721     True
# 25722     True
# Length: 25723, dtype: bool

# %%
#Index of lines
lines_to_drop = shark.loc[(shark.isnull().mean(axis=1) > 0.9)].index

# %%
#Drop the lines
shark.drop(labels=lines_to_drop, axis=0, inplace=True)

# %%
#Analysing the new shape
shark.shape
# Out:
# (6302, 24)

# %%
#Taking a new sample, it's more clear 
shark.sample(5)
# Out:
#      Case Number         Date    Year        Type      Country  \
# 851   2011.10.20  20-Oct-2011  2011.0  Unprovoked          USA
# 5460  1907.02.05  05-Feb-1907  1907.0  Unprovoked  NEW ZEALAND
# 5663  1893.10.16  16-Oct-1893  1893.0     Invalid      CROATIA
# 3009  1981.09.28  28-Sep-1981  1981.0  Unprovoked          USA
# 130   2017.06.17  17-Jun-2017  2017.0  Unprovoked        SPAIN
#
#                                Area                     Location    Activity  \
# 851                          Oregon      Newport, Lincoln County     Surfing
# 5460                   South Island                 Port Moeraki    Standing
# 5663   Primorje-Gorski Kotar County         Off Volusca, Opatija  small boat
# 3009                        Florida  Cocoa Beach, Brevard County     Surfing
# 130                    Ibiza Island             Playa den Bossa    Swimming
#
#                                   Name Sex   ...          Species   \
# 851                         Bobby Gumm    M  ...  White shark, 15'
# 5460               Mr. W. H. Hutcheson    M  ...               NaN
# 5663  4 passengers frightened by shark  NaN  ...           Invalid
# 3009                         Stan Wing    M  ...               NaN
# 130                               male    M  ...               NaN
#
#                               Investigator or Source  \
# 851                                       R. Collier
# 5460  R.D. Weeks, GSAF; Otago Daily Times, 1/13/1962
# 5663                                   C. Moore.GSAF
# 3009                 St. Petersburg Times, 10/1/1981
# 130                      Diario de Ibiza, 6/17/'2017
#
#                            pdf  \
# 851        2011.10.20-Gumm.pdf
# 5460  1907.02.05-Hutcheson.pdf
# 5663    1893.10.16-Opatija.pdf
# 3009       1981.09.28-Wing.pdf
# 130       2017.06.17-Spain.pdf
#
#                                            href formula  \
# 851   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5460  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5663  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3009  http://sharkattackfile.net/spreadsheets/pdf_di...
# 130   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 851   http://sharkattackfile.net/spreadsheets/pdf_di...    2011.10.20
# 5460  http://sharkattackfile.net/spreadsheets/pdf_di...    1907.02.05
# 5663  http://sharkattackfile.net/spreadsheets/pdf_di...    1893.10.16
# 3009  http://sharkattackfile.net/spreadsheets/pdf_di...    1981.09.28
# 130   http://sharkattackfile.net/spreadsheets/pdf_di...    2017.06.17
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 851     2011.10.20         5452.0         NaN         NaN
# 5460    1907.02.05          843.0         NaN         NaN
# 5663    1893.10.16          640.0         NaN         NaN
# 3009    1981.09.28         3294.0         NaN         NaN
# 130     2017.06.17         6173.0         NaN         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## CLEANING COLUMNS

# %%
#Analysing the % of columns null
shark.isnull().mean()>0.9
# Out:
# Case Number               False
# Date                      False
# Year                      False
# Type                      False
# Country                   False
# Area                      False
# Location                  False
# Activity                  False
# Name                      False
# Sex                       False
# Age                       False
# Injury                    False
# Fatal (Y/N)               False
# Time                      False
# Species                   False
# Investigator or Source    False
# pdf                       False
# href formula              False
# href                      False
# Case Number.1             False
# Case Number.2             False
# original order            False
# Unnamed: 22                True
# Unnamed: 23                True
# dtype: bool

# %%
#Mask to drop the columns which more than 90% of NaN 
shark.loc[: ,shark.isnull().mean()>0.9]
# Out:
#      Unnamed: 22 Unnamed: 23
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 6297         NaN         NaN
# 6298         NaN         NaN
# 6299         NaN         NaN
# 6300         NaN         NaN
# 6301         NaN         NaN
#
# [6302 rows x 2 columns]

# %%
#Index of columns
columns_to_drop = list(shark.loc[: ,shark.isnull().mean()>0.9].columns)
columns_to_drop
# Out:
# ['Unnamed: 22', 'Unnamed: 23']

# %%
#Drop the columns
shark.drop(columns=columns_to_drop, inplace=True)

# %%
#Taking a new sample with all columns displayed
pd.options.display.max_columns=None
shark.sample(10)
# Out:
#         Case Number                  Date    Year        Type  \
# 1041   2010.02.06.R  Reported 06-Feb-2010  2010.0    Provoked
# 371    2015.08.29.b           29-Aug-2015  2015.0  Unprovoked
# 1046     2010.02.01           01-Feb-2010  2010.0    Provoked
# 2340    1995.09.19.           19-Sep-1995  1995.0  Unprovoked
# 1259     2008.05.10           10-May-2008  2008.0  Unprovoked
# 1631     2004.10.10           10-Oct-2004  2004.0  Unprovoked
# 3329     1972.07.05           05-Jul-1972  1972.0     Invalid
# 382      2015.07.27           27-Jul-2015  2015.0         NaN
# 869    2011.09.11.a           11-Sep-2011  2011.0  Unprovoked
# 2201  1998.01.28.R   Reported 28-Jan-1998  1998.0     Invalid
#
#                Country               Area  \
# 1041       NEW ZEALAND       South Island
# 371                USA         California
# 1046       NEW ZEALAND       South Island
# 2340               USA            Florida
# 1259         AUSTRALIA  Western Australia
# 1631               USA         California
# 3329               USA         California
# 382          AUSTRALIA           Victoria
# 869   PAPUA NEW GUINEA   Central Province
# 2201         AUSTRALIA    New South Wales
#
#                                               Location         Activity  \
# 1041                                         Cosy Nook     Spearfishing
# 371   Morro Strand State Beach, San Luis Obispo County          Surfing
# 1046                                       Oreti Beach  Boogie Boarding
# 2340              Matanzas Bay Inlet, St. Johns County          Surfing
# 1259                                            Albany         Swimming
# 1631    Limantour Beach, Point Reyes National Seashore          Surfing
# 3329                       Laguna Beach, Orange County           Diving
# 382                                   Tyrendarra Beach          Surfing
# 869                            Hula, near Port Moresby     Kite Surfing
# 2201                                       Whale Beach     Spearfishing
#
#                 Name Sex   Age  \
# 1041   Aaron Muilwyk    M  NaN
# 371   Elinor Dempsey    F   54
# 1046      Lydia Ward    F   14
# 2340     Gavin Korth    M   19
# 1259      Jason Cull    M   37
# 1631    Paul de Jung    M  NaN
# 3329             NaN  NaN  NaN
# 382             male    M   40
# 869      Thomas Viot    M   30
# 2201            male    M   31
#
#                                                  Injury Fatal (Y/N)  \
# 1041  No injury, shark bit his speargun after he use...           N
# 371                         No injury, surfboard bitten           N
# 1046                 Stepped on shark PROVOKED INCIDENT           N
# 2340                          Left arm & hand lacerated           N
# 1259                     Severe lacerations to left leg           N
# 1631                                   Lower leg bitten           N
# 3329                 Sharks reportedly bit legs & fins          NaN
# 382                                      Injury to hand         NaN
# 869                            Lacerations to right leg           N
# 2201     Missing, thought to have been taken by a shark         NaN
#
#            Time                               Species   \
# 1041        NaN                       2 m to 3 m shark
# 371       10h25                White shark, 11' to 12'
# 1046      18h30                            1.5 m shark
# 2340        NaN                       1.8 m [6'] shark
# 1259      07h30                        White shark, 4m
# 1631      09h30  1.8 m to 2.4 m [6' to 8'] white shark
# 3329        NaN                  Questionable incident
# 382         NaN                                    NaN
# 869   Afternoon                        Tiger shark, 2m
# 2201      20h00        Shark involvement not confirmed
#
#                                  Investigator or Source  \
# 1041                          Southland Times, 2/6/2010
# 371                                    R. Collier, GSAF
# 1046  R.D. Weeks, GSAF;   K. Ritchie, ABC News, 2/1/...
# 2340                 Orlando Sentinel, 9/20/1995, p.C.3
# 1259                               Perth Now, 5/10/2008
# 1631                                   R. Collier, GSAF
# 3329                                 Unconfirmed Report
# 382                                                 NaN
# 869                    Sydney Morning Herald, 9/12/2011
# 2201                     Daily Telegraph, 1/28/1998.p.2
#
#                                   pdf  \
# 1041         2010.02.06.R-Muilwyk.pdf
# 371          2015.08.29.b-Dempsey.pdf
# 1046                            12.26
# 2340             1995.09.19-Korth.pdf
# 1259         2008.05.10-JasonCull.pdf
# 1631            2004.10.10-deJung.pdf
# 3329     1972.07.05-NV-California.pdf
# 382           2015.07.27-Victoria.pdf
# 869             2011.09.11.a-Viot.pdf
# 2201  1998.01.28.R-spearfisherman.pdf
#
#                                            href formula  \
# 1041  http://sharkattackfile.net/spreadsheets/pdf_di...
# 371   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1046  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2340  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1259  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1631  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3329  http://sharkattackfile.net/spreadsheets/pdf_di...
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...
# 869   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2201  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href  Case Number.1  \
# 1041  http://sharkattackfile.net/spreadsheets/pdf_di...   2010.02.06.R
# 371   http://sharkattackfile.net/spreadsheets/pdf_di...   2015.08.29.b
# 1046  http://sharkattackfile.net/spreadsheets/pdf_di...     2010.02.01
# 2340  http://sharkattackfile.net/spreadsheets/pdf_di...    1995.09.19.
# 1259  http://sharkattackfile.net/spreadsheets/pdf_di...     2008.05.10
# 1631  http://sharkattackfile.net/spreadsheets/pdf_di...     2004.10.10
# 3329  http://sharkattackfile.net/spreadsheets/pdf_di...     1972.07.05
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...     2015.07.27
# 869   http://sharkattackfile.net/spreadsheets/pdf_di...   2011.09.11.a
# 2201  http://sharkattackfile.net/spreadsheets/pdf_di...  1998.01.28.R
#
#       Case Number.2  original order
# 1041   2010.02.06.R          5262.0
# 371    2015.08.29.b          5932.0
# 1046     2010.02.01          5257.0
# 2340    1995.09.19.          3963.0
# 1259     2008.05.10          5044.0
# 1631     2004.10.10          4672.0
# 3329     1972.07.05          2974.0
# 382      2015.07.27          5921.0
# 869    2011.09.11.a          5434.0
# 2201  1998.01.28.R           4102.0

# %%
shark.shape
# Out:
# (6302, 22)

# %% [markdown]
# ## ANALYSING COLUMNS: Case Number.1, Case Number.2

# %%
shark.loc[shark['Case Number.1']==shark['Case Number']].shape[0]
# Out:
# 6278

# %%
shark.loc[shark['Case Number.1']!=shark['Case Number']]
# 4425                                      Beira
# 4949                 Haydarpasa jetty, Istanbul
# 5275                                     Savona
# 5358                                 Port Limon
# 5386                                      Ceuta
# 5488               Fort Pierce, St Lucie County
# 5777                                      Bahia
# 5883                     Tlacotalpan, Vera Cruz
# 5944                                        NaN
# 6009                                        NaN
# 6122                           Falmouth Harbour
#
#                                      Activity  \
# 34                                    Surfing
# 117                                       SUP
# 144                                Snorkeling
# 217                                   Surfing
# 314                              Spearfishing
# 334                                   Surfing
# 339                             Body boarding
# 390                                   Surfing
# 560                                    Diving
# 3522                             Spearfishing
# 3795                                      NaN
# 3880                                  Fishing
# 4403                                  Fishing
# 4425                                 Swimming
# 4949                                  Fishing
# 5275                                  Fishing
# 5358                                 Swimming
# 5386                                  Bathing
# 5488                                  Fishing
# 5777  Fell overboard from the steamship Chala
# 5883                                  Bathing
# 5944                           Fell overboard
# 6009                                 Swimming
# 6122                                      NaN
#
#                                        Name Sex       Age  \
# 34                             Ross Spowart    M       19
# 117                            Rolf Geyling    M       50
# 144                           Andres Rozada    M       33
# 217                                    male    M      NaN
# 314                              Keith Love    M      NaN
# 334                          Ryla Underwood    F        9
# 339                         Raymond Senensi    M       10
# 390                            Danny Miskin    M       38
# 560                                     NaN  NaN      NaN
# 3522                           Gungor Guven    M       36
# 3795                   Occupant: Hasan Olta    M      NaN
# 3880  Pollione Perrini & Fioravante Perini     M  33 & 37
# 4403                         Vittorio Speca  NaN       19
# 4425               Antonio De Almeida Pinto    M      NaN
# 4949                                2 males    M      NaN
# 5275                                    NaN    M      NaN
# 5358          August Schulke & Karl Schafer    M      NaN
# 5386                              a soldier    M      NaN
# 5488                            David Curry    M      NaN
# 5777                                   male    M      NaN
# 5883              a servant of General Diaz    M      NaN
# 5944         male from the whaler Albatross    M      NaN
# 6009                                 Hanson    M      NaN
# 6122                                    NaN  NaN      NaN
#
#                                                  Injury Fatal (Y/N)  \
# 34                 Lacerations to left knee & lower leg           N
# 117                    No injury, shark bit paddleboard           N
# 144                                               FATAL           Y
# 217               No injury: Knocked off board by shark           N
# 314   Bruised ribs & tail bone, speargun broken and ...           N
# 334                              Lower left leg injured         NaN
# 339   Lacerations & puncture wounds to right thigh, ...           N
# 390             No injury, shark bumped & damaged board           N
# 560                            4-inch laceration to arm           N
# 3522                                              FATAL           Y
# 3795                                         No injury            N
# 3880  Left foot & right hand bitten by netted shark ...           N
# 4403                Multiple injuries PROVOKED INCIDENT           Y
# 4425                                          No injury         NaN
# 4949                                          No injury           N
# 5275                                          No injury           N
# 5358                                              FATAL           Y
# 5386                                              FATAL           Y
# 5488  Lacerations to leg from hooked shark PROVOKED ...           N
# 5777                                              FATAL           Y
# 5883                                              FATAL           Y
# 5944                                              FATAL           Y
# 6009                                Leg severed at knee           N
# 6122                     Probable drowning & scavenging         NaN
#
#                Time                         Species   \
# 34            15h00                      White shark
# 117           07h45           White shark, 8' to 10'
# 144           17h00                              NaN
# 217             NaN                        2 m shark
# 314   09h30 / 10h00                  Bull sharks x 2
# 334           11h00  Shark involvement not confirmed
# 339           14h50                              NaN
://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
# 314   http://sharkattackfile.net/spreadsheets/pdf_di...  2015.01.24.b
# 334   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.11.07
# 339   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.10.28
# 390   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.07.10
# 560   http://sharkattackfile.net/spreadsheets/pdf_di...    2013.05.04
# 3522  http://sharkattackfile.net/spreadsheets/pdf_di...    1967/07.05
# 3795  http://sharkattackfile.net/spreadsheets/pdf_di...  1962.08.30.b
# 3880  http://sharkattackfile.net/spreadsheets/pdf_di...  1961.09,06.R
# 4403  http://sharkattackfile.net/spreadsheets/pdf_di...    1952.08.04
# 4425  http://sharkattackfile.net/spreadsheets/pdf_di...  1951.12.15.R
# 4949  http://sharkattackfile.net/spreadsheets/pdf_di...  1934.02.08.R
# 5275  http://sharkattackfile.net/spreadsheets/pdf_di...  1919.00.00.R
# 5358  http://sharkattackfile.net/spreadsheets/pdf_di...  1913.17.10.R
# 5386  http://sharkattackfile.net/spreadsheets/pdf_di...  1911.07.31.T
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...  1905.09.06.R
# 5777  http://sharkattackfile.net/spreadsheets/pdf_di...  1884.04.28.R
# 5883  http://sharkattackfile.net/spreadsheets/pdf_di...  1874.06.18.R
# 5944  http://sharkattackfile.net/spreadsheets/pdf_di...    1864.05.00
# 6009  http://sharkattackfile.net/spreadsheets/pdf_di...    1853.04.29
# 6122  http://sharkattackfile.net/spreadsheets/pdf_di...  1808.05.01.R
#
#      Case Number.2  original order
# 34      2018.04.03          6269.0
# 117   2017.07.20.a          6186.0
# 144     2017.05.06          6159.0
# 217     2016.09.15          6086.0
# 314   2016.01.24.b          5989.0
# 334     2015.12.23          5969.0
# 339   2015.10.28.a          5964.0
# 390     2015.07.10          5913.0
# 560     2014.05.04          5743.0
# 3522    1967.07.05          2781.0
# 3795  1962,08.30.b          2508.0
# 3880  1961.09.02.R          2423.0
# 4403    1952.08.05          1900.0
# 4425  1851.12.15.R          1878.0
# 4949  1934.02.08.R          1354.0
# 5275  1900.00.00.R          1028.0
# 5358  1913.07.10.R           945.0
# 5386  1911.07.31.R           917.0
# 5488  1905.09.06.R           815.0
# 5777  1884.04.38.R           526.0
# 5883  1876.06.18.R           420.0
# 5944    1864.05.00           359.0
# 6009    1853,94.29           294.0
# 6122  1808.06.01.R           181.0

# %%
shark.loc[shark['Case Number']==shark['Case Number.2']].shape[0]
# Out:
# 6298

# %%
shark.loc[shark['Case Number']!=shark['Case Number.2']]
#04 cells differents - The difference is only on formattion, so I drop the Case Number.2
# Out:
#        Case Number                  Date    Year        Type    Country  \
# 390     2015.07-10           10-Jul-2015  2015.0  Unprovoked        USA
# 4949  1934.01.08.R  Reported 08-Feb-1934  1934.0     Boating     TURKEY
# 5488           NaN  Reported 06-Sep-1905  1905.0    Provoked        USA
# 5944       1864.05              May-1864  1864.0  Unprovoked  MAURITIUS
#
#                              Area                         Location  \
# 390                    California  Huntington Beach, Orange County
# 4949                     Istanbul       Haydarpasa jetty, Istanbul
# 5488                      Florida     Fort Pierce, St Lucie County
# 5944  300 miles east of Mauritius                              NaN
#
#             Activity                            Name Sex   Age  \
# 390          Surfing                    Danny Miskin    M   38
# 4949         Fishing                         2 males    M  NaN
# 5488         Fishing                     David Curry    M  NaN
# 5944  Fell overboard  male from the whaler Albatross    M  NaN
#
#                                                  Injury Fatal (Y/N)   Time  \
# 390             No injury, shark bumped & damaged board           N  08h45
# 4949                                          No injury           N    NaN
# 5488  Lacerations to leg from hooked shark PROVOKED ...           N    NaN
# 5944                                              FATAL           Y    NaN
#
#              Species              Investigator or Source  \
# 390   White shark, 7'                    KTLA, 7/10/2015
# 4949              NaN                     C. Moore, GSAF
# 5488              NaN     Muncie Evening Press, 8/6/1913
# 5944              NaN  North Adams Transcript, 3/18/1898
#
#                            pdf  \
# 390      2015.07.10-Miskin.pdf
# 4949   1924.02.08.R-Turkey.pdf
# 5488    1905.09.06.R-Curry.pdf
# 5944  1864.05.00.Mauritius.pdf
#
#                                            href formula  \
# 390   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4949  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5944  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 390   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.07.10
# 4949  http://sharkattackfile.net/spreadsheets/pdf_di...  1934.02.08.R
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...  1905.09.06.R
# 5944  http://sharkattackfile.net/spreadsheets/pdf_di...    1864.05.00
#
#      Case Number.2  original order
# 390     2015.07.10          5913.0
# 4949  1934.02.08.R          1354.0
# 5488  1905.09.06.R           815.0
# 5944    1864.05.00           359.0

# %%
shark.drop(columns=['Case Number.2'], inplace=True)

# %%
shark.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#    original order
# 0          6303.0
# 1          6302.0
# 2          6301.0
# 3          6300.0
# 4          6299.0

# %% [markdown]
# ## ANALYSING THE 'Fatal (Y/N)' COLUMN

# %%
#Analysing the data of column Fatal (Y/N)
shark['Fatal (Y/N)'].value_counts()
# Out:
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# N             1
# M             1
# y             1
# 2017          1
# Name: Fatal (Y/N), dtype: int64

# %%
def change_no(name):
        return re.sub(' *N *', 'N', str(name))

# %%
shark['Fatal (Y/N)'] = shark['Fatal (Y/N)'].apply(change_no)

# %%
def change_yes(name):
    return re.sub('y', 'Y', str(name))

# %%
shark['Fatal (Y/N)'] = shark['Fatal (Y/N)'].apply(change_yes)

# %%
shark['Fatal (Y/N)'].value_counts()
# Out:
# N          4301
# Y          1389
# nan         539
# UNKNOWN      71
# M             1
# 2017          1
# Name: Fatal (Y/N), dtype: int64

# %% [markdown]
# ### Converting NaN to Unknown:

# %%
shark.loc[shark['Fatal (Y/N)']=='nan']
#Nan could be classified as UNKNOWN.
# Out:
#        Case Number                      Date    Year        Type  \
# 27    2018.04.15.c               15-Apr-2018  2018.0  Unprovoked
# 76      2017.10.01               01-Oct-2017  2017.0     Invalid
# 79    2017.09.24.b               24-Sep-2017  2017.0     Invalid
# 84    2017.09.15.b               15-Sep-2017  2017.0     Invalid
# 98    2017.08.26.b               26-Aug-2017  2017.0     Invalid
# ...            ...                       ...     ...         ...
# 6147    1767.00.00                      1767  1767.0     Invalid
# 6157    1733.00.00                      1733  1733.0     Invalid
# 6158    1723.00.00                      1723  1723.0  Unprovoked
# 6164  1642.00.00.b  Late 1600s Reported 1728  1642.0     Invalid
# 6232       ND.0081      No date, Before 1963     0.0     Invalid
#
#            Country                   Area         Location        Activity  \
# 27          BRAZIL             Pernambuco          Piedade        Swimming
# 76    SOUTH AFRICA  Western Cape Province      Dyer Island    Scuba Diving
# 79             USA               New York         Rockaway         Surfing
# 84    SOUTH AFRICA  Western Cape Province          Hawston    Scuba Diving
# 98           SPAIN              Castellón  Grao de Moncofa        Swimming
# ...            ...                    ...              ...             ...
# 6147        FRANCE           Côte d'Azur        St. Tropez         Bathing
# 6157       ICELAND            Bardestrand     Talkknefiord             NaN
# 6158        ROATAN                    NaN              NaN             NaN
# 6164        GUINEA                    NaN              NaN  Went overboard
# 6232           USA                 Hawaii   Portlock, Oahu          Diving
#
#                                Name Sex   Age  \
# 27                    Pablo de Melo    M   34
# 76                     Bradley Fick    M   31
# 79                   Michah Behrend    M   33
# 84                       Wayon Love    M   25
# 98                           female    F   11
# ...                             ...  ...  ...
# 6147                Samuel Matthews    M  NaN
# 6157                            NaN  NaN  NaN
# 6158                  Philip Ashton    M  NaN
# 6164  crew member of the Nieuwstadt    M  NaN
# 6232                  Val Valentine    M  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 27    Multiple severe injuries to arms and leg, leg ...         nan
# 76                                                FATAL         nan
# 79               Lacerations to right ankle, foot & toe         nan
# 84        FATAL, but death was probably due to drowning         nan
# 98                             Lacerations to left foot         nan
# ...                                                 ...         ...
# 6147                           Lacerations to arm & leg         nan
# 6157  Partial hominid remains recovered from shark, ...         nan
# 6158                                    Struck on thigh         nan
# 6164                                              FATAL         nan
# 6232  A 4.3 m [14'] shark made threat display. No in...         nan
#
#            Time                                      Species   \
# 27          NaN                                           NaN
# 76          NaN           Death may have been due to drowning
# 79        15h30                                  Questionable
# 84    Afternoon                                           NaN
# 98       Midday                Shark involvement questionable
# ...         ...                                           ...
# 6147        NaN       Description of shark does not ring true
# 6157        NaN  Shark involvement prior to death unconfirmed
# 6158        NaN                                           NaN
# 6164        NaN                                  Questionable
# 6232        NaN                                       Invalid
#
#                                  Investigator or Source  \
# 27                                     Globo, 4/16/2018
# 76                              All Africa, 10/11/2017
# 79                            S. Curatolo-Wageman, GSAF
# 84                                 Ground Up, 9/20/2017
# 98                 El Periodico Mediterraneo, 8/27/2017
# ...                                                 ...
# 6147                                                NaN
# 6157                                         E. Olafsen
# 6158                                      C.Moore, GSAF
# 6164  History of the Pyrates, by D. Defoe, Vol. 2, p.28
# 6232                                B. Sojka & D. Lloyd
#
#                               pdf  \
# 27        2018.04.15.c-deMelo.pdf
# 76            2017.10.01-Fick.pdf
# 79       2017.09.24.b-Behrend.pdf
# 84          2017.09.15.b-Love.pdf
# 98         2017.08.26.b-Spain.pdf
# ...                           ...
# 6147      1767.00.00-Matthews.pdf
# 6157       1733.00.00-Iceland.pdf
# 6158        1730.00.00-Ashton.pdf
# 6164  1642.00.00.b-Nieuwstadt.pdf
# 6232        ND-0081-Valentine.pdf
#
#                                            href formula  \
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...
# 76    http://sharkattackfile.net/spreadsheets/pdf_di...
# 79    http://sharkattackfile.net/spreadsheets/pdf_di...
# 84    http://sharkattackfile.net/spreadsheets/pdf_di...
# 98    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6147  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6157  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6158  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6164  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6232  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.c
# 76    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.10.01
# 79    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.24.b
# 84    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.15.b
# 98    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.08.26.b
# ...                                                 ...           ...
# 6147  http://sharkattackfile.net/spreadsheets/pdf_di...    1767.00.00
# 6157  http://sharkattackfile.net/spreadsheets/pdf_di...    1733.00.00
# 6158  http://sharkattackfile.net/spreadsheets/pdf_di...    1723.00.00
# 6164  http://sharkattackfile.net/spreadsheets/pdf_di...  1642.00.00.b
# 6232  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0081
#
#       original order
# 27            6276.0
# 76            6227.0
# 79            6224.0
# 84            6219.0
# 98            6205.0
# ...              ...
# 6147           156.0
# 6157           146.0
# 6158           145.0
# 6164           139.0
# 6232            71.0
#
# [539 rows x 21 columns]

# %%
#shark.loc[shark['Fatal (Y/N)']=='UNKNOWN']

# %%
def change_nan(name):
    return re.sub('nan', 'UNKNOWN', str(name))

# %%
shark['Fatal (Y/N)'] = shark['Fatal (Y/N)'].apply(change_nan)

# %%
shark['Fatal (Y/N)'].value_counts()
# Out:
# N          4301
# Y          1389
# UNKNOWN     610
# M             1
# 2017          1
# Name: Fatal (Y/N), dtype: int64

# %% [markdown]
# ### Converting '2017' to Unknown:

# %%
shark.loc[shark['Fatal (Y/N)']=='2017']
# Out:
#     Case Number         Date    Year      Type Country      Area  Location  \
# 786  2012.06.10  10-Jun-2012  2012.0  Provoked   ITALY  Sardinia  Muravera
#
#                                             Activity          Name Sex  Age  \
# 786  Attempting to rescue an injured & beached shark  Giorgio Zara    M  57
#
#                                        Injury Fatal (Y/N)     Time  \
# 786  Lower left leg injured PROVOKED ACCIDENT        2017  Morning
#
#              Species  Investigator or Source                  pdf  \
# 786  Blue shark, 2.5m    D. Puddo, 6/11/2012  2012.06.10-Zara.pdf
#
#                                           href formula  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...    2012.06.10
#
#      original order
# 786          5517.0

# %%
def change_nan(name):
    return re.sub('2017', 'UNKNOWN', str(name))

shark['Fatal (Y/N)'] = shark['Fatal (Y/N)'].apply(change_nan)

# %% [markdown]
# ### Converting 'M' to Unknown:

# %%
shark.loc[shark['Fatal (Y/N)']=='M']
# Out:
#       Case Number         Date    Year      Type           Country      Area  \
# 285  2016.04.18.b  18-Apr-2016  2016.0  Provoked  FRENCH POLYNESIA  Tuamotos
#
#          Location      Activity         Name Sex  Age  \
# 285  Makemo Atoll  Spearfishing  Hoata Iotua    M  22
#
#                                                 Injury Fatal (Y/N)     Time  \
# 285  Laceration to knee by speared shark PROVOKED I...           M  Morning
#
#                  Species  Investigator or Source                     pdf  \
# 285  Grey reef shark, 2 m   TNTV News, 4/19/2016  2016.04.18.b-Iotua.pdf
#
#                                           href formula  \
# 285  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 285  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.04.18.b
#
#      original order
# 285          6018.0

# %%
def change_nan(name):
    return re.sub('M', 'UNKNOWN', str(name))

shark['Fatal (Y/N)'] = shark['Fatal (Y/N)'].apply(change_nan)

# %%
shark['Fatal (Y/N)'].value_counts()
# Out:
# N          4301
# Y          1389
# UNKNOWN     612
# Name: Fatal (Y/N), dtype: int64

# %% [markdown]
# ### Detail: There are some data classified as 'UNKNOWN' where INJURY informns that it was 'FATAL', so:

# %%
shark[['Injury', 'Fatal (Y/N)']]
# Out:
#                                                  Injury Fatal (Y/N)
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6297                                              FATAL           Y
# 6298                                              FATAL           Y
# 6299                                              FATAL           Y
# 6300                                              FATAL           Y
# 6301  FATAL. "Shark bit him in half, carrying away t...           Y
#
# [6302 rows x 2 columns]

# %%
condition1 = shark['Injury']=='FATAL'
condition2 = shark['Fatal (Y/N)']=='UNKNOWN'
condition1 & condition2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6297    False
# 6298    False
# 6299    False
# 6300    False
# 6301    False
# Length: 6302, dtype: bool

# %%
shark[condition1 & condition2]
# Out:
#        Case Number                      Date    Year        Type  \
# 76      2017.10.01               01-Oct-2017  2017.0     Invalid
# 874   2011.08.28.b               28-Aug-2011  2011.0     Invalid
# 2230  1997.08.14.b               14-Aug-1997  1997.0     Invalid
# 2660    1989.10.08               08-Oct-1989  1989.0     Invalid
# 2674    1989.07.27               27-Jul-1989  1969.0     Invalid
# 2791  1987.00.00.b                      1987  1987.0     Invalid
# 2953    1983.01.15               15-Jan-1983  1983.0     Invalid
# 3811    1962.06.25               25-Jun-1962  1962.0     Invalid
# 4780  1940.00.00.b                      1940  1940.0     Invalid
# 5196    1923.11.02               02-Nov-1923  1923.0     Invalid
# 5425    1909.01.17               17-Jan-1909  1909.0     Invalid
# 5499    1905.03.25               25-Mar-1905  1905.0     Invalid
# 5577    1899.06.02               02-Jun-1899  1899.0     Invalid
# 5578    1899.05.28               28-May-1899  1899.0     Invalid
# 5806    1881.10.16               16-Oct-1881  1881.0     Invalid
# 5891  1873.06.09.R      Reported 09-Jun-1873  1873.0     Invalid
# 5906  1871.05.13.R      Reported 13-May 1871  1871.0     Invalid
# 5920    1869.04.10               10-Apr-1869  1869.0     Invalid
# 6104  1826.08.15.R      Reported 15-Aug-1826  1826.0  Unprovoked
# 6164  1642.00.00.b  Late 1600s Reported 1728  1642.0     Invalid
#
#            Country                   Area  \
# 76    SOUTH AFRICA  Western Cape Province
# 874      AUSTRALIA             Queensland
# 2230        MEXICO           Quintana Roo
# 2660           USA         North Carolina
# 2674       BERMUDA                    NaN
# 2791    MONTENEGRO           Adriatic Sea
# 2953  SOUTH AFRICA          KwaZulu-Natal
# 3811           USA                Florida
# 4780  SOUTH AFRICA          KwaZulu-Natal
# 5196     AUSTRALIA        New South Wales
# 5425           NaN                    NaN
# 5499     AUSTRALIA               Tasmania
# 5577   NEW ZEALAND           North Island
# 5578   PHILIPPINES                Negros
# 5806           USA                Florida
# 5891     AUSTRALIA        New South Wales
# 5906        GUYANA                    NaN
# 5920           NaN                    NaN
# 6104       ENGLAND             Cumberland
# 6164        GUINEA                    NaN
#
#                                                Location  \
# 76                                          Dyer Island
# 874                                      Fantome Island
# 2230                                Santa Rosa, Cozumel
# 2660  Between Wrightsville Beach & Carolina Beach, N...
# 2674                                                NaN
# 2791                                Mogren Beach, Budva
# 2953                                        Amanzimtoti
# 3811                    Fernandina Beach, Nassau County
# 4780                                       Winkelspruit
# 5196                                     Bellinger Head
# 5425                                   Near the equator
# 5499                                           Bridport
# 5577                                          East Cape
# 5578                                          Escalante
# 5806                     Pensacola Bay, Escambia County
# 5891                                         Newcastle
# 5906                                           Demerara
# 5920                                                NaN
# 6104                                         Whitehaven
# 6164                                                NaN
#
#                                                Activity  \
# 76                                         Scuba Diving
# 874                                            Swimming
# 2230                                       SCUBA diving
# 2660                                             Diving
# 2674                                       Scuba diving
# 2791                 Jumped into the water from a cliff
# 2953                                                NaN
# 3811  U.S. Airforce crewman reported missing after b...
# 4780                                                NaN
# 5196                                            Fishing
# 5425                                  Jumped overboard
# 5499                                            Bathing
# 5577         Attempting to land a boat from the Hinemoa
# 5578                                           Swimming
# 5806                                            Bathing
# 5891                                            Bathing
# 5906                                            Suicide
# 5920                                     Fell overboard
# 6104                                            Bathing
# 6164                                     Went overboard
#
#                                Name Sex   Age Injury Fatal (Y/N)  \
# 76                     Bradley Fick    M   31  FATAL     UNKNOWN
# 874                         Rooster    M   48  FATAL     UNKNOWN
# 2230                   Mike Jonatis    M   28  FATAL     UNKNOWN
# 2660                  Doug Nunnally    M   49  FATAL     UNKNOWN
# 2674                   Russian male    M   35  FATAL     UNKNOWN
# 2791        a student from Belgrade    M  NaN  FATAL     UNKNOWN
# 2953                     black male    M  NaN  FATAL     UNKNOWN
# 3811                           male    M  NaN  FATAL     UNKNOWN
# 4780                  Indian female    F  NaN  FATAL     UNKNOWN
# 5196                           male    M  NaN  FATAL     UNKNOWN
# 5425                  Thomas Butler    M   36  FATAL     UNKNOWN
# 5499                 Charles Taylor  NaN  NaN  FATAL     UNKNOWN
# 5577                    N. Buchanan    M  NaN  FATAL     UNKNOWN
# 5578                  Captain Tilly    M  NaN  FATAL     UNKNOWN
# 5806               Anthony McDonald    M   18  FATAL     UNKNOWN
# 5891                   Joseph Henry    M  NaN  FATAL     UNKNOWN
# 5906                          Grant    M  NaN  FATAL     UNKNOWN
# 5920            Christian Frederick    M  NaN  FATAL     UNKNOWN
# 6104                          child  NaN  NaN  FATAL     UNKNOWN
# 6164  crew member of the Nieuwstadt    M  NaN  FATAL     UNKNOWN
#
http://sharkattackfile.net/spreadsheets/pdf_di...
# 6164  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 76    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.10.01
# 874   http://sharkattackfile.net/spreadsheets/pdf_di...  2011.08.28.b
# 2230  http://sharkattackfile.net/spreadsheets/pdf_di...  1997.08.14.b
# 2660  http://sharkattackfile.net/spreadsheets/pdf_di...    1989.10.08
# 2674  http://sharkattackfile.net/spreadsheets/pdf_di...    1989.07.27
# 2791  http://sharkattackfile.net/spreadsheets/pdf_di...  1987.00.00.b
# 2953  http://sharkattackfile.net/spreadsheets/pdf_di...    1983.01.15
# 3811  http://sharkattackfile.net/spreadsheets/pdf_di...    1962.06.25
# 4780  http://sharkattackfile.net/spreadsheets/pdf_di...  1940.00.00.b
# 5196  http://sharkattackfile.net/spreadsheets/pdf_di...    1923.11.02
# 5425  http://sharkattackfile.net/spreadsheets/pdf_di...    1909.01.17
# 5499  http://sharkattackfile.net/spreadsheets/pdf_di...    1905.03.25
# 5577  http://sharkattackfile.net/spreadsheets/pdf_di...    1899.06.02
# 5578  http://sharkattackfile.net/spreadsheets/pdf_di...    1899.05.28
# 5806  http://sharkattackfile.net/spreadsheets/pdf_di...    1881.10.16
# 5891  http://sharkattackfile.net/spreadsheets/pdf_di...  1873.06.09.R
# 5906  http://sharkattackfile.net/spreadsheets/pdf_di...  1871.05.13.R
# 5920  http://sharkattackfile.net/spreadsheets/pdf_di...    1869.04.10
# 6104  http://sharkattackfile.net/spreadsheets/pdf_di...  1826.08.15.R
# 6164  http://sharkattackfile.net/spreadsheets/pdf_di...  1642.00.00.b
#
#       original order
# 76            6227.0
# 874           5429.0
# 2230          4073.0
# 2660          3643.0
# 2674          3629.0
# 2791          3512.0
# 2953          3350.0
# 3811          2492.0
# 4780          1523.0
# 5196          1107.0
# 5425           878.0
# 5499           804.0
# 5577           726.0
# 5578           725.0
# 5806           497.0
# 5891           412.0
# 5906           397.0
# 5920           383.0
# 6104           199.0
# 6164           139.0

# %%
def condicoes(shark):
    if shark['Fatal (Y/N)']=='UNKNOWN':
        if shark['Injury']=='FATAL':
            return re.sub('UNKNOWN', 'Y', shark['Fatal (Y/N)'])
        else:
            return re.sub('UNKNOWN', 'UNKNOWN', shark['Fatal (Y/N)'])
    if shark['Fatal (Y/N)']=='Y':
        return re.sub('Y', 'Y', shark['Fatal (Y/N)'])
    if shark['Fatal (Y/N)']=='N':
        return re.sub('N', 'N', shark['Fatal (Y/N)'])

# %%
shark['Fatal (Y/N)']=shark.apply(condicoes, axis=1)

# %%
shark['Fatal (Y/N)'].value_counts()
# Out:
# N          4301
# Y          1409
# UNKNOWN     592
# Name: Fatal (Y/N), dtype: int64

# %%
shark.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#    original order
# 0          6303.0
# 1          6302.0
# 2          6301.0
# 3          6300.0
# 4          6299.0

# %% [markdown]
# ### Exporting the cleaned database to csv:

# %%
#Exporting only the fatal accidents to csv file:
fatal_clean = shark[shark['Fatal (Y/N)']=='Y']
fatal_clean.to_csv('./Exported_Files/shark_fatal_clean.csv', index=False)

# %%
#Exporting only the non-fatal accidents to csv file:
fatal_clean = shark[shark['Fatal (Y/N)']=='N']
fatal_clean.to_csv('./Exported_Files/shark_non_fatal_clean.csv', index=False)

# %%
#Exporting only the unknown accidents to csv file:
fatal_clean = shark[shark['Fatal (Y/N)']=='UNKNOWN']
fatal_clean.to_csv('./Exported_Files/shark_non_fatal_clean.csv', index=False)

# %% [markdown]
# # PRESENTING RESULTS

# %%
print('% Fatal =',(shark['Fatal (Y/N)']=='Y').mean())
print('% Non-Fatal =',(shark['Fatal (Y/N)']=='N').mean())
print('% Unknown =',(shark['Fatal (Y/N)']=='UNKNOWN').mean())
# Out:
# % Fatal = 0.22357981593145032
# % Non-Fatal = 0.6824817518248175
# % Unknown = 0.09393843224373215

# %%
fatal_y= (shark['Fatal (Y/N)']=='Y').sum()
fatal_n= (shark['Fatal (Y/N)']=='N').sum()
fatal_un=(shark['Fatal (Y/N)']=='UNKNOWN').sum()
print('Qty Fatal =',fatal_y,'\nQty Non-Fatal =',fatal_n,'\nQty Unknown =',fatal_un)
# Out:
# Qty Fatal = 1409
# Qty Non-Fatal = 4301
# Qty Unknown = 592

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Fatal (Y)', 'Non-Fatal (N)', 'Unknown'
sizes = [fatal_y, fatal_n, fatal_un]
explode = (0.1, 0, 0)  # only "explode" the 1rst slice (i.e. 'Fatal)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%',
        shadow=True, startangle=100)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.savefig('Results_Quantity_Fatal.png', format='png')
plt.show()

#model_graph_source = https://matplotlib.org/3.3.1/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py

# %% [markdown]
# Even if we consider all UNKNOWN cases as Fatal, the Non-Fatal cases still greather than Fatal:

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Fatal', 'Non-Fatal'
sizes = [fatal_y+fatal_un, fatal_n]
explode = (0.1, 0)  # only "explode" the 1rst slice (i.e. 'Fatal)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%',
        shadow=True, startangle=100)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.savefig('Results_Quantity_Without_Unknown.png', format='png')
plt.show()

#model_graph_source = https://matplotlib.org/3.3.1/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py

# %% [markdown]
# # CURIOSITY:
# In this regard, we remind our visitors that more people drown in a single year in the United States than have been killed by sharks throughout the entire world in the last two centuries

# %%
(shark['Fatal (Y/N)']=='Y').sum()
# Out:
# 1409

# %%
#Overview about the years:
shark['Date'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       25-Jun-2018
# 1       18-Jun-2018
# 2       09-Jun-2018
# 3       08-Jun-2018
# 4       04-Jun-2018
#            ...
# 6297    Before 1903
# 6298    Before 1903
# 6299      1900-1905
# 6300      1883-1889
# 6301      1845-1853
# Name: Date, Length: 6302, dtype: object>

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
d = (shark['Fatal (Y/N)']=='Y').sum()
labels = 'Fatal (1845 - 2018) Entire World', 'Drown per year EUA'
sizes = [d, 3536]
explode = (0.1, 0)  # only "explode" the 1rst slice (i.e. 'Fatal)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%',
        shadow=True, startangle=100)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.savefig('Curiosity.png', format='png')
plt.show()

#drown source: https://www.cdc.gov/homeandrecreationalsafety/water-safety/waterinjuries-factsheet.html#:~:text=From%202005%2D2014%2C%20there%20were,drowning%20in%20boating%2Drelated%20incidents.&text=About%20one%20in%20five%20people,are%20children%2014%20and%20younger.
#model_graph_source = https://matplotlib.org/3.3.1/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py

# %% [markdown]
# # EXTRA: HOW MANY FATAL WAS PROVOKED?

# %%
condition1=(shark['Fatal (Y/N)']=='Y')
condition2=(shark['Type']=='Provoked')
shark[condition1 & condition2]['Fatal (Y/N)'].value_counts()
# Out:
# Y    19
# Name: Fatal (Y/N), dtype: int64

# %%
condition1=(shark['Fatal (Y/N)']=='Y')
condition2=(shark['Type']=='Unprovoked')
shark[condition1 & condition2]['Fatal (Y/N)'].value_counts()
# Out:
# Y    1182
# Name: Fatal (Y/N), dtype: int64

# %%
condition1=(shark['Fatal (Y/N)']=='Y')
condition2=(shark['Type']=='Boatomg')
shark[condition1 & condition2]['Fatal (Y/N)'].value_counts()
# Out:
# Series([], Name: Fatal (Y/N), dtype: int64)

# %%
shark['Type'].value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
#shark.query('`Fatal (Y/N)` == "Y" and Type == "Provoked"')

# %% [markdown]
# # EXTRA: HOW MANY FATAL WAS WOMENS?

# %%
condition1=(shark['Fatal (Y/N)']=='Y')
condition2=(shark['Sex ']=='F')
shark[condition1 & condition2]['Fatal (Y/N)'].value_counts()
# Out:
# Y    108
# Name: Fatal (Y/N), dtype: int64

# %%
condition1=(shark['Fatal (Y/N)']=='Y')
condition2=(shark['Sex ']=='M')
shark[condition1 & condition2]['Fatal (Y/N)'].value_counts()
# Out:
# Y    1190
# Name: Fatal (Y/N), dtype: int64

# %%
(shark['Sex ']=='F').value_counts()
# Out:
# False    5665
# True      637
# Name: Sex , dtype: int64

# %%
shark.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'original order'],
#       dtype='object')

# %% [markdown]
# # EXTRA: HOW OF THE FATAL DEATHS WAS CAUSED BY THE SPECIE WITH LARGER NUMBER OF CASES?

# %%
shark['Species '].value_counts()
# Out:
# White shark                                           163
# Shark involvement prior to death was not confirmed    105
# Invalid                                               102
# Shark involvement not confirmed                        88
# Tiger shark                                            73
#                                                      ...
# Hammerhead shark, 5'                                    1
# "a very large shark"                                    1
# Blue pointer, 16'                                       1
# No shark invovlement                                    1
# Blacktip reef shark                                     1
# Name: Species , Length: 1549, dtype: int64

# %%
x=shark.groupby('Species ').count()[['Fatal (Y/N)','Case Number']]

# %%
x.nlargest(1,columns=['Case Number'], keep='first')
# Out:
#              Fatal (Y/N)  Case Number
# Species
# White shark          163          163

# %%
condition3 = (shark['Species ']=='White shark')

# %%
print('The quantity of fatal acidents caused by White Sharks is:',shark[condition1 & condition3]['Fatal (Y/N)'].count())
# Out:
# The quantity of fatal acidents caused by White Sharks is: 44

# %%
print('The % of deaths caused by White Shark Attacks is:',44/163 * 100)
# Out:
# The % of deaths caused by White Shark Attacks is: 26.993865030674847

# 4267                                            Kérkira
# 4285                                            Opatija
# 4437                                Off Royal Residence
# 4854                               Bar Beach, Newcastle
# 4888                                South Steyne, Manly
# 4889                          West Beach, near Adelaide
# 4936                             Susak (Rijeka, Istria)
# 5231                                            Coogee
# 5379                                       Isla Cabrera
# 5545                                     Windmill Beach
# 5921                                            Trieste
#
#                                                Activity  \
# 155                                             Surfing
# 271                                             Surfing
# 613                               Swimming / snorkeling
# 871                                       Body boarding
# 986                                            Swimming
# 996                                             Surfing
# 1051                                           Standing
# 1096                                            Surfing
# 1555                                       Scuba diving
# 1582                         Spearfishing (Free diving)
# 1665                       Swimming, poaching perlemoen
# 1747                                      Body boarding
# 2004                                            Surfing
# 2115                                    Boogie boarding
# 2182                                      Body Boarding
# 2210                                       Spearfishing
# 2245                                Fishing for octopus
# 2344  Abalone diving using Hookah (near calving whales)
# 2653                         Free diving & spearfishing
# 2767                          Scuba Diving for scallops
# 3078                                      Hookah Diving
# 3214                           Scuba diving for abalone
# 3279                                 Diving for abalone
# 3296                          Free diving, Spearfishing
# 3356                                           Swimming
# 3514        Spearfishing, dived to pick up a float line
# 3561                                           Swimming
# 3793                       Spearfishing with Scuba gear
# 3876                                           Swimming
# 4171                                           Swimming
# 4194                                           Swimming
# 4200                                           Swimming
# 4247                                           Swimming
# 4267                                 Swimming off yacht
# 4285                                           Swimming
# 4437                                           Swimming
# 4854                                           Swimming
# 4888                                           Swimming
# 4889  Swimming. Passer-by, Len Bedford, heard him sh...
# 4936                                           Swimming
# 5231                                           Swimming
# 5379                                Fell into the water
# 5545                                           Swimming
# 5921                                                NaN
#
#                                                   Name Sex   Age  \
# 155                                   Laeticia Brouwer    F   17
# 271                                        Ben Gerring    M   29
# 613                         Burgert Van Der Westhuizen    M   74
# 871                                  Kyle James Burden    M   21
# 986                                Khanyisile Momoza      M   29
# 996                                   Nicholas Edwards    M   31
# 1051                                     Lloyd Skinner    M   37
# 1096                                   Gerhard van Zyl    M   25
# 1555                                   Jarrod Stehbens    M   23
# 1582                                      Henri Murray    M   22
# 1665                                 Nkosinathi Mayaba    M   21
# 1747                                     David Bornman    M   19
# 2004                                      Jevan Wright    M   17
# 2115                                Hercules Pretorius    M   14
# 2182                                       Anton deVos    M   20
# 2210                                    Ian James Hill    M   39
# 2245                                    Shizuo Nakachi    M   55
# 2344                                   David Alan Weir    M   29
# 2653                                 Gerjo Van Niekerk    M   29
# 2767                                   Terrance Gibson    M   47
# 3078                              Jose Larenas-Miranda    M  NaN
# 3214                                      Robert Slack    M   37
# 3279                                      Terry Manuel    M   26
# 3296                                 Al Schneppershoff    M   37
# 3356                                   Stanislav Klepa    M   34
# 3514                                     Robert Bartle    M   23
# 3561                                     Josef Treliac    M   33
# 3793                                    Maurizio Sarra    M   28
# 3876                                       Sabit Plana    M   19
# 4171                              Derek Garth Prinsloo    M  NaN
# 4194                                       Rupert Wade    M   57
# 4200                                      Peter Savino    M   25
# 4247                                      Jack Smedley    M   40
# 4267                                         Margoulis    F   15
# 4285                                      Carla Podzum    F   32
# 4437                                      Vanda Pierri    F   16
# 4854                                        John Welsh    M   32
# 4888                                       David Paton    M   14
# 4889                                       Ray Bennett    M   13
# 4936                                       Agnes Novak    F   18
# 5231                                   Milton Coughlan    M   18
# 5379                           the governor of Cabrera    M  NaN
# 5545  John Hendrick Adrian Chandler, a prisoner of war    M   29
# 5921                                              male    M  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 155                                               FATAL           Y
# 271                                               FATAL           Y
# 613                                               FATAL           Y
# 871                                               FATAL           Y
# 986                                               FATAL           Y
# 996                                               FATAL           Y
# 1051                                              FATAL           Y
# 1096                                              FATAL           Y
# 1555                                              FATAL           Y
# 1582                                              FATAL           Y
# 1665                                FATAL, leg severed            Y
# 1747  FATAL, left thigh, buttocks, back of spine, ab...           Y
# 2004                                              FATAL           Y
# 2115                                              FATAL           Y
# 2182                       FATAL, hands & calf bitten             Y
# 2210                                              FATAL           Y
# 2245                              FATAL, legs severed             Y
# 2344  FATAL, head, shoulder and arm severed, remains...           Y
# 2653                                              FATAL           Y
# 2767                                              FATAL           Y
# 3078                                            FATAL             Y
# 3214                                              FATAL           Y
# 3279                         FATAL, right leg severed             Y
# 3296                                 FATAL, leg bitten            Y
# 3356                                              FATAL           Y
# 3514                             FATAL, "bitten in two"           Y
# 3561                                              FATAL           Y
# 3793            FATAL, multiple injuries to both legs             Y
# 3876                FATAL, hand severed & legs bitten             Y
# 4171                                              FATAL           Y
# 4194                               FATAL, knee bitten             Y
# 4200  FATAL, seen with arm in mouth of shark. Body n...           Y
# 4247                                              FATAL           Y
# 4267                                              FATAL           Y
# 4285                                              FATAL           Y
# 4437  FATAL, body not recovered Another man was also...           Y
# 4854       FATAL, buttocks, ankle & right elbow bitten            Y
# 4888  FATAL, taken by shark, body not recovered. Twe...           Y
# 4889                                             FATAL            Y
# 4936                                              FATAL           Y
# 5231                 FATAL, both arms & shoulder bitten           Y
# 5379                                              FATAL           Y
# 5545  Right leg bitten & foot severed, right arm bit...           Y
# 5921                                              FATAL           Y
#
#                  Time     Species   \
# 155             16h00  White shark
# 271             16h00  White shark
# 613             11h30  White shark
# 871             13h26  White shark
# 986               NaN  White shark
# 996             08h05  White shark
# 1051            15h15  White shark
# 1096            15h30  White shark
# 1555            16h10  White shark
# 1582            15h45  White shark
# 1665            15h00  White shark
# 1747            14h30  White shark
# 2004            13h00  White shark
# 2115            11h15  White shark
# 2182            09h55  White shark
# 2210            14h00  White shark
# 2245              NaN  White shark
# 2344            15h00  White shark
# 2653            12h05  White shark
# 2767              NaN  White shark
# 3078            11h00  White shark
# 3214        Afternoon  White shark
# 3279              NaN  White shark
# 3296            16h45  White shark
# 3356            10h30  White shark
# 3514            11h00  White shark
# 3561              NaN  White shark
# 3793            10h20  White shark
# 3876  Early afternoon  White shark
# 4171            07h30  White shark
# 4194            15h15  White shark
# 4200            13h30  White shark
# 4247              NaN  White shark
# 4267              NaN  White shark
# 4285              NaN  White shark
# 4437              NaN  White shark
# 4854            15h20  White shark
# 4888            15h00  White shark
# 4889            18h00  White shark
# 4936              NaN  White shark
# 5231            15h30  White shark
# 5379              NaN  White shark
# 5545            14h15  White shark
# 5921              NaN  White shark
#
#                                  Investigator or Source  \
# 155                                      B. Myatt, GSAF
# 271                                Perth Now, 5/31/2016
# 613                            JBayNews.com, 10/11/2013
# 871                      Sunshine Coast Daily, 9/5/2011
# 986                               Cape Argus, 9/25/2010
# 996                           The Australian, 8/17/2010
# 1051                    L. Cohen, Times Live, 1/12/2010
# 1096                         Cape Argus, 8/30/2009, p.1
# 1555                     Adelaide Advertiser, 8/26/2005
# 1582                        News24.com; SABC; H. Steele
# 1665              J. Smetherham & B. Ndenze, Cape Times
# 1747  E. Ritter, GSAF;      http://www.wavescape.co....
# 2004                                     T. Peake, GSAF
# 2115                                   A. Gifford, GSAF
# 2182                                   A. Gifford, GSAF
# 2210                                   A. Gifford, GSAF
# 2245  Okinawa Weekly Times, 7/19/1997 editon; Ryukyu...
# 2344  The Advertiser, 9/13/1995, p.2; H. Edwards, pp...
# 2653                                    M. Levine, GSAF
# 2767                    A. Sharpe, p.127; J. West, ASAF
# 3078                         J. McCosker &  A.C. Engana
# 3214  Times, 8/1/1975, Yuma Daily Sun, 8/1/1975; C. ...
# 3279                         H. Hall; A. Sharpe, p.124;
# 3296  Washington Post, 9/12/1973; J. McCosker & R.N....
# 3356                        R. Rocconi & C. Moore, GSAF
# 3514  H. Edwards, pp.35-42; H.D. Baldridge, p.28; A....
# 3561       R. Rocconi; A. De Maddalena & C. Moore, GSAF
# 3793  A. De Maddalena & C. Moore, GSAF; Carletti (19...
# 3876  The Mid-Ocean News, 9/28/1961; H.D. Baldridge,...
# 4171                                    M. Levine, GSAF
# 4194  V.M. Coppleson, p.155; F. Walker; F. Schwartz,...
# 4200  D. Miller & R. Collier, R. Collier, pp.16-17; ...
# 4247  V.M. Coppleson (1958), p.261; A. Xuereb; A. Bu...
# 4267                                             MEDSAF
# 4285                                         R. Rocconi
# 4437                               A De Maddalena, GSAF
# 4854  V.M. Coppleson (1958), pp.77 & 234; A. Sharpe,...
# 4888  V.M. Coppleson (1958), pp.67 & 234; A. Sharpe,...
# 4889  Sydney Morning Herald, 1/23/1936; V.M. Copples...
# 4936  NY Times, 7/10/1934, p.15; V.M. Coppleson (195...
# 5231  V.M. Coppleson.N.4. (1933); V.M. Coppleson (19...
# 5379                                     C. Moore. GSAF
# 5545                                    M. Levine, GSAF
# 5921  A. De Maddalena; Radovanovi (1965), Soldo & Ja...
#
#                                         pdf  \
# 155                2017.04.17.a Brouwer.pdf
# 271                  2016.05.31-Gerring.pdf
# 613            2013.10.11-Vd-Westhuizen.pdf
# 871                 2011.09.04.a-Burden.pdf
# 986                   2010.09.21-Momoza.pdf
# 996                  2010.08.17-Edwards.pdf
# 1051                 2010.01.12-Skinner.pdf
# 1096                  2009.08.29-VanZyl.pdf
# 1555              2005.08.24.b-Stehbens.pdf
# 1582             2005.06.04-HenriMurray.pdf
# 1665                 2004.06.02-Mayabai.pdf
# 1747                 2003.09.12-Bornman.pdf
# 2004                  2000.09.25-Wright.pdf
# 2115               1999.07.15-Pretorius.pdf
# 2210  http://sharkattackfile.net/spreadsheets/pdf_di...  1997.12.28.b
# 2245  http://sharkattackfile.net/spreadsheets/pdf_di...    1997.07.12
# 2344  http://sharkattackfile.net/spreadsheets/pdf_di...    1995.09.11
# 2653  http://sharkattackfile.net/spreadsheets/pdf_di...    1989.11.18
# 2767  http://sharkattackfile.net/spreadsheets/pdf_di...    1987.09.18
# 3078  http://sharkattackfile.net/spreadsheets/pdf_di...    1980.01.05
# 3214  http://sharkattackfile.net/spreadsheets/pdf_di...  1975.07.30.a
# 3279  http://sharkattackfile.net/spreadsheets/pdf_di...    1974.01.09
# 3296  http://sharkattackfile.net/spreadsheets/pdf_di...    1973.09.09
# 3356  http://sharkattackfile.net/spreadsheets/pdf_di...    1971.09.07
# 3514  http://sharkattackfile.net/spreadsheets/pdf_di...    1967.08.19
# 3561  http://sharkattackfile.net/spreadsheets/pdf_di...    1966.08.16
# 3793  http://sharkattackfile.net/spreadsheets/pdf_di...    1962.09.02
# 3876  http://sharkattackfile.net/spreadsheets/pdf_di...  1961.09.24.b
# 4171  http://sharkattackfile.net/spreadsheets/pdf_di...    1958.01.09
# 4194  http://sharkattackfile.net/spreadsheets/pdf_di...    1957.07.15
# 4200  http://sharkattackfile.net/spreadsheets/pdf_di...    1957.04.28
# 4247  http://sharkattackfile.net/spreadsheets/pdf_di...    1956.07.20
# 4267  http://sharkattackfile.net/spreadsheets/pdf_di...  1956.00.00.f
# 4285  http://sharkattackfile.net/spreadsheets/pdf_di...    1955.08.26
# 4437  http://sharkattackfile.net/spreadsheets/pdf_di...  1951.08.17.a
# 4854  http://sharkattackfile.net/spreadsheets/pdf_di...    1937.02.13
# 4888  http://sharkattackfile.net/spreadsheets/pdf_di...    1936.02.04
# 4889  http://sharkattackfile.net/spreadsheets/pdf_di...    1936.01.22
# 4936  http://sharkattackfile.net/spreadsheets/pdf_di...    1934.08.21
# 5231  http://sharkattackfile.net/spreadsheets/pdf_di...    1922.02.04
# 5379  http://sharkattackfile.net/spreadsheets/pdf_di...    1912.00.00
# 5545  http://sharkattackfile.net/spreadsheets/pdf_di...    1901.07.30
# 5921  http://sharkattackfile.net/spreadsheets/pdf_di...    1868.09.01
#
#       original order
# 155           6148.0
# 271           6032.0
# 613           5690.0
# 871           5432.0
# 986           5317.0
# 996           5307.0
# 1051          5252.0
# 1096          5207.0
# 1555          4748.0
# 1582          4721.0
# 1665          4638.0
# 1747          4556.0
# 2004          4299.0
# 2115          4188.0
# 2182          4121.0
# 2210          4093.0
# 2245          4058.0
# 2344          3959.0
# 2653          3650.0
# 2767          3536.0
# 3078          3225.0
# 3214          3089.0
# 3279          3024.0
# 3296          3007.0
# 3356          2947.0
# 3514          2789.0
# 3561          2742.0
# 3793          2510.0
# 3876          2427.0
# 4171          2132.0
# 4194          2109.0
# 4200          2103.0
# 4247          2056.0
# 4267          2036.0
# 4285          2018.0
# 4437          1866.0
# 4854          1449.0
# 4888          1415.0
# 4889          1414.0
# 4936          1367.0
# 5231          1072.0
# 5379           924.0
# 5545           758.0
# 5921           382.0
